# %% [markdown]
# # **Problem Statement**
# To build a multiclass classification model using a custom convolutional neural network in TensorFlow.
# To build a CNN based model which can accurately detect melanoma a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ## Lets Importing Skin Cancer Data
#
# **Importing all the important libraries**

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

import warnings
warnings.filterwarnings('ignore')

# %%
# If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# The dataset consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC, and all subsets were divided into the same number of images, with the exception of melanomas and moles, whose images are slightly dominant.
#
#
# The data set contains the following diseases:
#
#
#
# *  Actinic keratosis
# *  Basal cell carcinoma
# *  Dermatofibroma
# *  Melanoma
# *  Nevus
# *  Pigmented benign keratosis
# *  Seborrheic keratosis
# *  Squamous cell carcinoma
# *  Vascular lesion

# %%
# Defining the path for train and test images
root_path = '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration'
data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_test = pathlib.Path(root_path + '/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# **Load using keras.preprocessing**
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.
#
# **Create a dataset**
#
# Define some parameters for the loader:

# %%
batch_size = 32 
img_height = 180 
img_width = 180

# %% [markdown]
# Now Lets Use 80% of the images for training, and 20% for validation.

# %%
# Lets use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
# Lets resize images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='training',
            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
# Lets use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
# Lets resize images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='validation',
            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %% [markdown]
# ### Lets List out all the classes of skin cancer and store them in a list.

# %%
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# # Visualize the data
#
# * Lets create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
plt.figure(figsize=(10,10))

for i in range(len(class_names)):
    filtered_ds = train_ds.filter(lambda x, l: tf.math.equal(l[0], i))
    for image, label in filtered_ds.take(1):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(image[0].numpy().astype('uint8'))
        plt.title(class_names[label.numpy()[0]])
        plt.axis('off')

# %% [markdown]
# * The **image_batch** is a tensor of the shape **(32, 180, 180, 3)**. This is a batch of **32 images **of shape **180x180x3** (the last dimension refers to color channels RGB).
#
# * The **label_batch** is a tensor of the shape **(32,),** these are corresponding labels to the 32 images.
#
# * **Dataset.cache()** keeps the images in memory after they're loaded off disk during the first epoch.
#
# * **Dataset.prefetch()** overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Create the model
#
# **Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use** layers.experimental.preprocessing.Rescaling **to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]**

# %%
num_class = 9
model = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(scale = 1./255, input_shape = (180,180,3)),

    layers.Conv2D(32,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2),    

    layers.Conv2D(64,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2),

    layers.Conv2D(128,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2),

    layers.Flatten(),
    layers.Dense(128,activation='relu'),

    layers.Dense(num_class, activation='softmax')
])

# %% [markdown]
# # Lets Compile the model
#
# * Choose an appropirate optimiser and loss function for model training

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 128)               7929984
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 8,024,393
# Trainable params: 8,024,393
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 99s 1s/step - loss: 1.9904 - accuracy: 0.2930 - val_loss: 1.6820 - val_accuracy: 0.3870
# Epoch 2/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.7285 - accuracy: 0.3917 - val_loss: 1.5894 - val_accuracy: 0.4452
# Epoch 3/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.4952 - accuracy: 0.4682 - val_loss: 1.4377 - val_accuracy: 0.5123
# Epoch 4/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.3388 - accuracy: 0.5262 - val_loss: 1.4468 - val_accuracy: 0.4832
# Epoch 5/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.2597 - accuracy: 0.5592 - val_loss: 1.3647 - val_accuracy: 0.5257
# Epoch 6/20
# 56/56 [==============================] - 2s 42ms/step - loss: 1.1516 - accuracy: 0.5993 - val_loss: 1.4351 - val_accuracy: 0.5302
# Epoch 7/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.0614 - accuracy: 0.6177 - val_loss: 1.4245 - val_accuracy: 0.5145
# Epoch 8/20
# 56/56 [==============================] - 2s 41ms/step - loss: 1.0241 - accuracy: 0.6345 - val_loss: 1.4669 - val_accuracy: 0.5503
# Epoch 9/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.9753 - accuracy: 0.6468 - val_loss: 1.5390 - val_accuracy: 0.5078
# Epoch 10/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.9422 - accuracy: 0.6607 - val_loss: 1.6295 - val_accuracy: 0.5280
# Epoch 11/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.8869 - accuracy: 0.6842 - val_loss: 1.5057 - val_accuracy: 0.5235
# Epoch 12/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.7626 - accuracy: 0.7227 - val_loss: 1.6239 - val_accuracy: 0.5190
# Epoch 13/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6778 - accuracy: 0.7539 - val_loss: 1.8532 - val_accuracy: 0.5302
# Epoch 14/20
# 56/56 [==============================] - 2s 41ms/step - loss: 0.6120 - accuracy: 0.7762 - val_loss: 1.7322 - val_accuracy: 0.5302
# Epoch 15/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.6012 - accuracy: 0.7857 - val_loss: 1.9640 - val_accuracy: 0.5302
# Epoch 16/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.5278 - accuracy: 0.8097 - val_loss: 2.0275 - val_accuracy: 0.5280
# Epoch 17/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.5104 - accuracy: 0.8231 - val_loss: 1.7212 - val_accuracy: 0.5101
# Epoch 18/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.4602 - accuracy: 0.8337 - val_loss: 2.1673 - val_accuracy: 0.5615
# Epoch 19/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.3920 - accuracy: 0.8610 - val_loss: 2.3507 - val_accuracy: 0.5011
# Epoch 20/20
# 56/56 [==============================] - 2s 42ms/step - loss: 0.3729 - accuracy: 0.8622 - val_loss: 2.7084 - val_accuracy: 0.5257

# %% [markdown]
# # Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Checking the Overfitting or Underfitting of the model
#
# - The model is clearly overfitting model.
#
# - The training accuracy is gradually increasing.
#
# * The validation accuracy is fluctuating around 50%.
#
# - The loss on training set decreases after each epoch but in case of the validation loss, its increasing after decreasing for few initial epochs.
#
# - The model memorized the data instead of generalizing and learning real features and general relationships.

# %%
# choosing an appropriate data augumentation strategy. 

data_augmentation = keras.Sequential([
    layers.experimental.preprocessing.RandomFlip(mode='horizontal_and_vertical', input_shape= (img_height, img_width, 3)),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    ])

# %%
# Visualising how your augmentation strategy works for one instance of training image.


for image, label in train_ds.take(1):
  plt.title("Original Image")
  plt.imshow(image[0]/255)
  plt.figure(figsize=(10,10))
  for i in range(9):
    augmented_image = data_augmentation(image, training=True)
    ax = plt.subplot(3, 3, i+1)
    plt.title("Augmented Image")
    plt.imshow(augmented_image[0]/255)
    plt.axis("off")

# %% [markdown]
# # Now Lets Create the model, compile and train the model
#
# **Along with augmentation, adding dropout considering previous experimentation is overfitted**

# %%
num_class = 9
model = tf.keras.Sequential([
    data_augmentation,
    layers.experimental.preprocessing.Rescaling(scale = 1./255, input_shape = (180,180,3)),

    layers.Conv2D(32,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),    
    layers.Dropout(0.2),

    layers.Conv2D(64,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),
    layers.Dropout(0.2),

    layers.Conv2D(128,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),
    layers.Dropout(0.2),

    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dropout(0.2),

    layers.Dense(num_class, activation='softmax')
])

# %% [markdown]
# # Lets Compiling the model

# %%
#Compiling the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %% [markdown]
# # Training the model

# %%
#retrain your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 5s 73ms/step - loss: 2.2813 - accuracy: 0.2355 - val_loss: 1.9753 - val_accuracy: 0.3445
# Epoch 2/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.9173 - accuracy: 0.2941 - val_loss: 1.8807 - val_accuracy: 0.3132
# Epoch 3/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.7631 - accuracy: 0.3549 - val_loss: 1.9149 - val_accuracy: 0.2819
# Epoch 4/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.6908 - accuracy: 0.3901 - val_loss: 1.6148 - val_accuracy: 0.4094
# Epoch 5/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.6466 - accuracy: 0.4057 - val_loss: 1.6364 - val_accuracy: 0.4139
# Epoch 6/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.6627 - accuracy: 0.3895 - val_loss: 1.5975 - val_accuracy: 0.4228
# Epoch 7/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.6296 - accuracy: 0.4029 - val_loss: 1.6105 - val_accuracy: 0.4474
# Epoch 8/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.5722 - accuracy: 0.4297 - val_loss: 1.5915 - val_accuracy: 0.4228
# Epoch 9/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.5563 - accuracy: 0.4325 - val_loss: 1.5393 - val_accuracy: 0.4609
# Epoch 10/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.5486 - accuracy: 0.4520 - val_loss: 1.5286 - val_accuracy: 0.4519
# Epoch 11/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.5582 - accuracy: 0.4576 - val_loss: 1.5194 - val_accuracy: 0.4407
# Epoch 12/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.5111 - accuracy: 0.4554 - val_loss: 1.4935 - val_accuracy: 0.4720
# Epoch 13/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.4398 - accuracy: 0.5033 - val_loss: 1.4579 - val_accuracy: 0.4899
# Epoch 14/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.4049 - accuracy: 0.5006 - val_loss: 1.3627 - val_accuracy: 0.5235
# Epoch 15/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.3519 - accuracy: 0.5195 - val_loss: 1.3880 - val_accuracy: 0.4989
# Epoch 16/20
# 56/56 [==============================] - 4s 70ms/step - loss: 1.3292 - accuracy: 0.5312 - val_loss: 1.3991 - val_accuracy: 0.4989
# Epoch 17/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.3353 - accuracy: 0.5273 - val_loss: 1.3494 - val_accuracy: 0.5034
# Epoch 18/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.3252 - accuracy: 0.5374 - val_loss: 1.3728 - val_accuracy: 0.5034
# Epoch 19/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.3495 - accuracy: 0.5279 - val_loss: 1.3539 - val_accuracy: 0.5324
# Epoch 20/20
# 56/56 [==============================] - 4s 71ms/step - loss: 1.2950 - accuracy: 0.5435 - val_loss: 1.4320 - val_accuracy: 0.5168

# %% [markdown]
# # Lets Visualize the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Checking the Overfitting or Underfitting of the model
# ### Lets Compare the improvement of the model we got now to the previous model run?
#
# - The application of data augmentation and dropout layer reduced overfitting.
# - Results on training and validation datasets are much closer.
# - Overall accuracy is not high.

# %% [markdown]
# # Lets Find the distribution of classes in the training dataset.

# %%
class_count=[]
for i in class_names:
    class_count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,8))
plt.bar(class_names,class_count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
#   - seborrheic keratosis Has the least number of samples
#
# ###  the classed that have data with proportionate number of samples are as followed
#   - pigmented benign keratosis
#   - melanoma
#   - basal cell carcinoma
#   - nevus

# %% [markdown]
# Lets Rectify the class imbalance
#
# **Note:** We can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use Augmentor, the following general procedure is followed:
#
# 1. Instantiate a Pipeline object pointing to a directory containing your initial image data set.
# 2. Define a number of operations to perform on this data set using your Pipeline object.
# 3. Execute these operations by calling the Pipeline’s sample() method.

# %%
path_to_training_dataset='/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/'

import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F17A4CF5D10>: 100%|██████████| 500/500 [00:19<00:00, 26.04 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F17A662EB50>: 100%|██████████| 500/500 [00:19<00:00, 25.92 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F17BC033C90>: 100%|██████████| 500/500 [00:20<00:00, 24.63 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3872x2592 at 0x7F1798689050>: 100%|██████████| 500/500 [01:24<00:00,  5.95 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=964x672 at 0x7F179878D250>: 100%|██████████| 500/500 [01:38<00:00,  5.10 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F1799FCD810>: 100%|██████████| 500/500 [00:20<00:00, 24.79 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F1810217450>: 100%|██████████| 500/500 [00:44<00:00, 11.27 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F17BC112F10>: 100%|██████████| 500/500 [00:19<00:00, 25.41 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F17A6675A50>: 100%|██████████| 500/500 [00:20<00:00, 24.49 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# **Lets see the distribution of augmented data after adding new images to the original training data.**

# %%
from glob import glob

path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025825.jpg_0b94b652-78f2-4349-8b13-c4e034a79c63.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024511.jpg_e69dc105-51c1-457e-b740-b275301054f6.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0028854.jpg_d9acbad0-0d7b-421a-abc1-b05c34175cad.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000364.jpg_50ce086b-cbbf-471c-99c4-a82f7d882143.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000319.jpg_faed1e89-d558-4a67-80f8-7ee625889a20.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000272.jpg_de610add-57fa-4b74-b7bc-9d2cf6f1f69f.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000272.jpg_dd2f13f7-47b2-42cf-8c46-877ff951b844.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000328.jpg_ad270f1f-c74a-46de-841f-bc60059f5e94.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000229.jpg_af4a26ad-691f-4fb0-924e-7f56f6ef1d2c.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000542.jpg_9efc83fc-c4be-4dfc-b201-9eb95607f3f3.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000236.jpg_64c4f708-faa2-4430-a3ce-6381f847e6d0.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000272.jpg_dacc100b-1553-49da-8e5e-db93da17a75f.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026525.jpg_9e57f9c2-27b9-4dd5-9130-3b825db01d13.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026857.jpg_b02db136-b930-45c5-9e82-fdb1d3f9faca.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000336.jpg_2ff05db8-7d43-47b6-b879-9e8f8a590e6a.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000496.jpg_69ad35b2-3480-4403-bc49-430a48273795.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000335.jpg_3432d461-37be-4a92-a36f-3726330595e9.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000433.jpg_bb9fe9fa-2b78-49d4-84b8-d0c9c3e8bff3.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000360.jpg_4cb2e6ed-f1e7-4a41-9e8f-2ac62d4d28b3.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000538.jpg_ea76ff0a-70fd-41b1-bb25-5c411992617a.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0026171.jpg_793d75ff-c79a-479b-9817-01ead09d0567.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000062.jpg_addedaab-61de-4b0a-b5d5-dd3c1c8468af.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0024468.jpg_c3ad7a0f-0e96-4c24-9786-dc86a0d03ff6.jpg',
#  '/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0

# seborrheic keratosis          500
# pigmented benign keratosis    500
# vascular lesion               500
# squamous cell carcinoma       500
# melanoma                      500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# # Lets Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# # Lets Create a training dataset

# %%
data_dir_train="/content/gdrive/MyDrive/Upgrad/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# Lets Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# # Creating the model

# %%
tf.keras.backend.clear_session()

num_class = 9
model = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(scale = 1./255, input_shape = (180,180,3)),
    
    layers.Conv2D(32,3,padding='same'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size = 2),    
    layers.Dropout(0.2),

    layers.Conv2D(64,3,padding='same'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size = 2),
    layers.Dropout(0.2),

    layers.Conv2D(128,3,padding='same'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size = 2),
    layers.Dropout(0.2),

    layers.Flatten(),
    layers.Dense(128),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.2),

    layers.Dense(num_class, activation='softmax')
])

# %% [markdown]
# # Lets compile the model by choosing optimizer and loss function

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # Lets Train model

# %%
epochs = 30

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 37s 206ms/step - loss: 1.6856 - accuracy: 0.3783 - val_loss: 1.6261 - val_accuracy: 0.3742
# Epoch 2/30
# 169/169 [==============================] - 40s 231ms/step - loss: 1.3447 - accuracy: 0.5067 - val_loss: 2.5803 - val_accuracy: 0.3267
# Epoch 3/30
# 169/169 [==============================] - 35s 202ms/step - loss: 1.1693 - accuracy: 0.5727 - val_loss: 1.7019 - val_accuracy: 0.4113
# Epoch 4/30
# 169/169 [==============================] - 35s 199ms/step - loss: 1.0397 - accuracy: 0.6157 - val_loss: 1.6884 - val_accuracy: 0.3972
# Epoch 5/30
# 169/169 [==============================] - 36s 209ms/step - loss: 0.9248 - accuracy: 0.6662 - val_loss: 1.2434 - val_accuracy: 0.5301
# Epoch 6/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.8161 - accuracy: 0.7116 - val_loss: 1.3153 - val_accuracy: 0.5360
# Epoch 7/30
# 169/169 [==============================] - 35s 201ms/step - loss: 0.7327 - accuracy: 0.7444 - val_loss: 1.2300 - val_accuracy: 0.5509
# Epoch 8/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.6037 - accuracy: 0.7925 - val_loss: 0.9899 - val_accuracy: 0.6518
# Epoch 9/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.5327 - accuracy: 0.8144 - val_loss: 0.9039 - val_accuracy: 0.6852
# Epoch 10/30
# 169/169 [==============================] - 35s 201ms/step - loss: 0.4229 - accuracy: 0.8526 - val_loss: 0.9869 - val_accuracy: 0.6511
# Epoch 11/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.3768 - accuracy: 0.8724 - val_loss: 0.8103 - val_accuracy: 0.7149
# Epoch 12/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.3013 - accuracy: 0.9006 - val_loss: 0.7725 - val_accuracy: 0.7246
# Epoch 13/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.2786 - accuracy: 0.9041 - val_loss: 0.6972 - val_accuracy: 0.7617
# Epoch 14/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.2463 - accuracy: 0.9130 - val_loss: 0.9382 - val_accuracy: 0.7030
# Epoch 15/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.2410 - accuracy: 0.9171 - val_loss: 0.7401 - val_accuracy: 0.7298
# Epoch 16/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.2122 - accuracy: 0.9262 - val_loss: 0.7116 - val_accuracy: 0.7461
# Epoch 17/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.1936 - accuracy: 0.9321 - val_loss: 0.6373 - val_accuracy: 0.7758
# Epoch 18/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.1874 - accuracy: 0.9330 - val_loss: 0.6523 - val_accuracy: 0.7699
# Epoch 19/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.1806 - accuracy: 0.9332 - val_loss: 0.7121 - val_accuracy: 0.7595
# Epoch 20/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.1810 - accuracy: 0.9362 - val_loss: 0.7234 - val_accuracy: 0.7543
# Epoch 21/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.1912 - accuracy: 0.9264 - val_loss: 0.6367 - val_accuracy: 0.7966
# Epoch 22/30
# 169/169 [==============================] - 35s 201ms/step - loss: 0.1558 - accuracy: 0.9425 - val_loss: 0.7434 - val_accuracy: 0.7580
# Epoch 23/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.1493 - accuracy: 0.9444 - val_loss: 0.7397 - val_accuracy: 0.7810
# Epoch 24/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.1547 - accuracy: 0.9407 - val_loss: 0.7560 - val_accuracy: 0.7713
# Epoch 25/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.1542 - accuracy: 0.9410 - val_loss: 0.7419 - val_accuracy: 0.7988
# Epoch 26/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.1411 - accuracy: 0.9457 - val_loss: 0.6139 - val_accuracy: 0.8129
# Epoch 27/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.1450 - accuracy: 0.9455 - val_loss: 0.7110 - val_accuracy: 0.7832
# Epoch 28/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.1516 - accuracy: 0.9403 - val_loss: 0.6833 - val_accuracy: 0.8040
# Epoch 29/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.1361 - accuracy: 0.9470 - val_loss: 0.6780 - val_accuracy: 0.8092
# Epoch 30/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.1546 - accuracy: 0.9453 - val_loss: 0.8171 - val_accuracy: 0.7624

# %% [markdown]
# # Lets Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# With only Dropout, without BatchNormalization
tf.keras.backend.clear_session()

num_class = 9
model = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(scale = 1./255, input_shape = (180,180,3)),
    
    layers.Conv2D(32,3,padding='same'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size = 2),    
    layers.Dropout(0.2),

    layers.Conv2D(64,3,padding='same'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size = 2),
    layers.Dropout(0.2),

    layers.Conv2D(128,3,padding='same'),
    layers.Activation('relu'),
    layers.MaxPooling2D(pool_size = 2),
    layers.Dropout(0.2),

    layers.Flatten(),
    layers.Dense(128),
    layers.Activation('relu'),
    layers.Dropout(0.2),

    layers.Dense(num_class, activation='softmax')
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


epochs = 30

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 36s 201ms/step - loss: 2.2627 - accuracy: 0.1385 - val_loss: 2.1885 - val_accuracy: 0.1403
# Epoch 2/30
# 169/169 [==============================] - 35s 202ms/step - loss: 2.1795 - accuracy: 0.1369 - val_loss: 2.1850 - val_accuracy: 0.1403
# Epoch 3/30
# 169/169 [==============================] - 35s 199ms/step - loss: 2.1692 - accuracy: 0.1530 - val_loss: 2.0553 - val_accuracy: 0.2294
# Epoch 4/30
# 169/169 [==============================] - 34s 197ms/step - loss: 1.8053 - accuracy: 0.3147 - val_loss: 1.5687 - val_accuracy: 0.4187
# Epoch 5/30
# 169/169 [==============================] - 35s 199ms/step - loss: 1.4990 - accuracy: 0.4340 - val_loss: 1.4540 - val_accuracy: 0.4499
# Epoch 6/30
# 169/169 [==============================] - 35s 198ms/step - loss: 1.3315 - accuracy: 0.4885 - val_loss: 1.2398 - val_accuracy: 0.5174
# Epoch 7/30
# 169/169 [==============================] - 34s 198ms/step - loss: 1.2028 - accuracy: 0.5427 - val_loss: 1.2316 - val_accuracy: 0.5316
# Epoch 8/30
# 169/169 [==============================] - 34s 197ms/step - loss: 1.0912 - accuracy: 0.5901 - val_loss: 1.0465 - val_accuracy: 0.6095
# Epoch 9/30
# 169/169 [==============================] - 35s 198ms/step - loss: 1.0147 - accuracy: 0.6250 - val_loss: 1.0599 - val_accuracy: 0.6147
# Epoch 10/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.8859 - accuracy: 0.6686 - val_loss: 0.9854 - val_accuracy: 0.6355
# Epoch 11/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.8117 - accuracy: 0.6938 - val_loss: 0.8852 - val_accuracy: 0.6793
# Epoch 12/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.7461 - accuracy: 0.7220 - val_loss: 0.8623 - val_accuracy: 0.6860
# Epoch 13/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.6630 - accuracy: 0.7530 - val_loss: 0.7649 - val_accuracy: 0.7186
# Epoch 14/30
# 169/169 [==============================] - 35s 201ms/step - loss: 0.6234 - accuracy: 0.7663 - val_loss: 0.7254 - val_accuracy: 0.7223
# Epoch 15/30
# 169/169 [==============================] - 35s 203ms/step - loss: 0.5686 - accuracy: 0.7884 - val_loss: 0.8323 - val_accuracy: 0.6941
# Epoch 16/30
# 169/169 [==============================] - 36s 204ms/step - loss: 0.5124 - accuracy: 0.8112 - val_loss: 0.7475 - val_accuracy: 0.7439
# Epoch 17/30
# 169/169 [==============================] - 35s 203ms/step - loss: 0.5159 - accuracy: 0.8073 - val_loss: 0.6658 - val_accuracy: 0.7528
# Epoch 18/30
# 169/169 [==============================] - 35s 203ms/step - loss: 0.4434 - accuracy: 0.8299 - val_loss: 0.6932 - val_accuracy: 0.7624
# Epoch 19/30
# 169/169 [==============================] - 35s 203ms/step - loss: 0.3984 - accuracy: 0.8414 - val_loss: 0.6707 - val_accuracy: 0.7788
# Epoch 20/30
# 169/169 [==============================] - 36s 204ms/step - loss: 0.4062 - accuracy: 0.8425 - val_loss: 0.6340 - val_accuracy: 0.7944
# Epoch 21/30
# 169/169 [==============================] - 36s 204ms/step - loss: 0.3843 - accuracy: 0.8553 - val_loss: 0.6485 - val_accuracy: 0.7892
# Epoch 22/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.3489 - accuracy: 0.8702 - val_loss: 0.6512 - val_accuracy: 0.7944
# Epoch 23/30
# 169/169 [==============================] - 34s 198ms/step - loss: 0.3333 - accuracy: 0.8709 - val_loss: 0.6871 - val_accuracy: 0.7936
# Epoch 24/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.3043 - accuracy: 0.8845 - val_loss: 0.7003 - val_accuracy: 0.7825
# Epoch 25/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.2944 - accuracy: 0.8876 - val_loss: 0.6437 - val_accuracy: 0.8114
# Epoch 26/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.3037 - accuracy: 0.8843 - val_loss: 0.6890 - val_accuracy: 0.8062
# Epoch 27/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.2953 - accuracy: 0.8869 - val_loss: 0.6703 - val_accuracy: 0.8077
# Epoch 28/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.2800 - accuracy: 0.8978 - val_loss: 0.6527 - val_accuracy: 0.8151
# Epoch 29/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.2540 - accuracy: 0.9004 - val_loss: 0.7078 - val_accuracy: 0.8085
# Epoch 30/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.2867 - accuracy: 0.8961 - val_loss: 0.6894 - val_accuracy: 0.8070

# %% [markdown]
# # Lets Visualize Results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Result Analysis

# %% [markdown]
# - Changes done for data imbalance helped in improving training and validation accuracy.
#
# - On top of data imbalance changes, tried two options
#   - With dropout and batch normalization
#   - With only dropout
#
# - Even though validation accuracy increased, still there is 0.1 gap between training and validation accuracy.

# %%
#checking the performance on the test set 

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_test,
    seed=123,
    batch_size=118,
    image_size=(img_height,img_width)
)

y_true=[]
y_pred=[]
for images, labels in test_ds.take(1):
  y_true=list(labels.numpy())
  predict_x=model.predict(images) 
  y_pred=np.argmax(predict_x,axis=1)
  print(classification_report(y_true,y_pred,target_names=class_names))
  print("Accuracy on test dataset : ",accuracy_score(y_true,y_pred))
# Out:
# Found 118 files belonging to 9 classes.
# 4/4 [==============================] - 0s 89ms/step
#                             precision    recall  f1-score   support
#
#          actinic keratosis       0.25      0.06      0.10        16
#       basal cell carcinoma       0.32      0.44      0.37        16
#             dermatofibroma       0.00      0.00      0.00        16
#                   melanoma       0.24      0.31      0.27        16
#                      nevus       0.26      0.56      0.36        16
# pigmented benign keratosis       0.48      0.62      0.54        16
#       seborrheic keratosis       0.00      0.00      0.00         3
#    squamous cell carcinoma       0.43      0.19      0.26        16
#            vascular lesion       0.50      0.67      0.57         3
#
#                   accuracy                           0.31       118
#                  macro avg       0.28      0.32      0.27       118
#               weighted avg       0.28      0.31      0.27       118
#
# Accuracy on test dataset :  0.3135593220338983
